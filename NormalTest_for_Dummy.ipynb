# %%
# Importación Librerías
# =======================================================================================================================
import pandas as pd                                                                                                          # Manejo de datos
import numpy as np                                                                                                         # Manejo de arrays
import scipy.stats as stats                                                                                                            # Estadìstica
import matplotlib.pyplot as plt                                                                           # Generación de Gráficas
import seaborn as sns                                                                                           # Generación de Gráficas
import warnings                                                                                                     # Configuración warnings

# %%
# Definición de nivel significancia
# ========================================================================================================================
alpha = 0.001

# %%
# Definición de configuración de gráficos y mensajes de advertencia
# ========================================================================================================================
sns.set()
warnings.filterwarnings('ignore')

# %%
# Generación de distribución exponencial
# ========================================================================================================================
mu, sigma = 10, 2  # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)
sns.distplot(s, hist=True, kde=False)
plt.show()
stat, p_val = normaltest(s)
print('Normaltest para la distribución normal')
print('Normaltest stats es: {:1.5f} '.format(stat))
print('Normaltest p-value es: {:1.6f}'.format(p_val))
if p_val < alpha: print('p_val es menor a alpha (0.001) por lo que hay evidencia muestral para rechazar la hipótesis que la distribución es normal')
if p_val > alpha: print('p_val es mayor a alpha (0.001) por lo que no hay evidencia muestral para rechazar la hipótesis que la distribución es normal')
print('\n')

# Generación de distribución uniforme
# ========================================================================================================================
a, b = 1, 2  # number of trials, probability of each trial
u = np.random.uniform(a,b,1000)
sns.distplot(u, hist=True, kde=False)
plt.show()
stat, p_val = normaltest(u)

print('Normaltest para la distribución uniforme')
print('Normaltest stats es: {:1.5f} '.format(stat))
print('Normaltest p-value es: {:1.6f} '.format(p_val))
if p_val < alpha: print('p_val es menor a alpha (0.001) por lo que hay evidencia muestral para rechazar la hipótesis que la distribución es normal')
if p_val > alpha: print('p_val es mayor a alpha (0.001) por lo que no hay evidencia muestral para rechazar la hipótesis que la distribución es normal')
print('\n')

# Generación de distribución exponencial
# ========================================================================================================================
e = np.random.exponential(10,1000)
sns.distplot(e, hist=True, kde=False)
plt.show()
stat, p_val = normaltest(e)

print('Normaltest para la distribución exponencial')
print('Normaltest stats es: {:1.5f} '.format(stat))
print('Normaltest p-value es: {:1.6f} '.format(p_val))
if p_val < alpha: print('p_val es menor a alpha (0.001) por lo que hay evidencia muestral para rechazar la hipótesis que la distribución es normal')
if p_val > alpha: print('p_val es mayor a alpha (0.001) por lo que no hay evidencia muestral para rechazar la hipótesis que la distribución es normal')
print('\n')

# Generación de distribución logistica
# ========================================================================================================================
loc, scale = 10, 1
g = np.random.logistic(loc, scale, 1000)
sns.distplot(g, hist=True, kde=False)
plt.show()
stat, p_val = normaltest(g)

print('Normaltest para la distribución logística')
print('Normaltest stats es: {:1.5f} '.format(stat))
print('Normaltest p-value es: {:1.6f} '.format(p_val))
if p_val < alpha: print('p_val es menor a alpha (0.001) por lo que hay evidencia muestral para rechazar la hipótesis que la distribución es normal')
if p_val > alpha: print('p_val es mayor a alpha (0.001) por lo que no hay evidencia muestral para rechazar la hipótesis que la distribución es normal')
print('\n')
# Out:
# Normaltest para la distribución normal
# Normaltest stats es: 3.45382
# Normaltest p-value es: 0.177833
# p_val es mayor a alpha (0.001) por lo que no hay evidencia muestral para rechazar la hipótesis que la distribución es normal
# Normaltest para la distribución uniforme
# Normaltest stats es: 721.27746
# Normaltest p-value es: 0.000000
# p_val es menor a alpha (0.001) por lo que hay evidencia muestral para rechazar la hipótesis que la distribución es normal
# Normaltest para la distribución exponencial
# Normaltest stats es: 389.57594
# Normaltest p-value es: 0.000000
# p_val es menor a alpha (0.001) por lo que hay evidencia muestral para rechazar la hipótesis que la distribución es normal
# Normaltest para la distribución logística
# Normaltest stats es: 21.51434
# Normaltest p-value es: 0.000021
# p_val es menor a alpha (0.001) por lo que hay evidencia muestral para rechazar la hipótesis que la distribución es normal
